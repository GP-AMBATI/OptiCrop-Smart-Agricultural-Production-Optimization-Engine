# %%
import shutil
from pathlib import Path
import os
print('notebook cwd', os.getcwd())
src = Path(r'c:\Users\ashis\Desktop\project\Crop_recommendation.csv')
dst_dir = Path(r'c:\Users\ashis\Desktop\project\dataset')
dst_dir.mkdir(exist_ok=True)
dst = dst_dir / 'crop_recommendation.csv'
print('Copying', src, 'to', dst)
shutil.copyfile(src, dst)
print('Done')
# Out:
# Copying Crop_recommendation.csv to dataset\crop_recommendation.csv
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 8
#       4 dst_dir = Path('dataset')
#       5 dst_dir.mkdir(exist_ok=True)
#       6 dst = dst_dir / 'crop_recommendation.csv'
#       7 print('Copying', src, 'to', dst)
# ----> 8 shutil.copyfile(src, dst)
#       9 print('Done')
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\shutil.py:313, in copyfile(src, dst, follow_symlinks)
#     311     os.symlink(os.readlink(src), dst)
#     312 else:
# --> 313     with open(src, 'rb') as fsrc:
#     314         try:
#     315             with open(dst, 'wb') as fdst:
#     316                 # macOS
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Crop_recommendation.csv'
