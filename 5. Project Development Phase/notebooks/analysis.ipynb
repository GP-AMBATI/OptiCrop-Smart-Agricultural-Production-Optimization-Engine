# %% [markdown]
# # OptiCrop Data Analysis
# This notebook contains exploratory data analysis for the crop recommendation dataset.

# %%
import pandas as pd
from pathlib import Path
dataset = Path('dataset') / 'crop_recommendation.csv'
df = pd.read_csv(dataset)
print(df.shape)
print(df.head())
print(df['label'].value_counts().head(10))
