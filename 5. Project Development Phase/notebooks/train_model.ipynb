# %% [markdown]
# # Train OptiCrop Model
# This notebook trains the crop recommendation model and saves artifacts for deployment.

# %%
from model import train_and_save, ensure_artifacts
ensure_artifacts()
best_model, results = train_and_save()
print('Best model selected:', best_model)
print('Training metrics:', results['selected_model'])
print('Artifacts saved: model.pkl, scaler.pkl, label_encoder.pkl')
